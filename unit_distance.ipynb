# %%
import pandas as pd

# %%
units = pd.read_csv("gen_data/units_N1851-01.csv",encoding='utf8').drop(["id.1"],axis=1)
units = units.set_index(units["id_property"])
units.head(3)
# Out:
#                 id  id_property  category   area  floor  beds_basic  \
# id_property
# 10043        24588        10043         3  100.0      2           4
# 10043        24589        10043         3  100.0      1           4
# 10043        24590        10043         3  100.0      0           4
#
#              beds_additional  garden  twin_bed  unit_wardrobe_closet  ...  \
# id_property                                                           ...
# 10043                      2       1         1                     1  ...
# 10043                      2       1         1                     1  ...
# 10043                      0       1         1                     1  ...
#
#              mosquito_net  paying_amex  paying_master  paying_visa  \
# id_property
# 10043                   0            0              0            0
# 10043                   0            0              0            0
# 10043                   0            0              0            0
#
#              paying_maestro  card_payment  language_sk  \
# id_property
# 10043                     0             0            0
# 10043                     0             0            0
# 10043                     0             0            0
#
#              property_internet_location  location_turistcomplex  \
# id_property
# 10043                                 0                       0
# 10043                                 0                       0
# 10043                                 0                       0
#
#              in_food_local_speciality
# id_property
# 10043                               0
# 10043                               0
# 10043                               0
#
# [3 rows x 391 columns]

# %%
facility = pd.read_csv("gen_data/facility_nvls.csv").drop(["Unnamed: 0"], axis=1)
facility = facility.set_index(facility["id_property"])
facility.head()
# Out:
#              id_property_unit  id_property        facility_sub_grp  \
# id_property
# 1817                        0         1817                     NaN
# 1817                     3623         1817  unit_bedroom_equipment
# 1817                     3623         1817  unit_bedroom_equipment
# 1817                     3623         1817  unit_bedroom_equipment
# 1817                     3623         1817  unit_bedroom_equipment
#
#                           facility_code value new_values
# id_property
# 1817                             garden    on          1
# 1817                           twin_bed    on          1
# 1817               unit_wardrobe_closet    on          1
# 1817         unit_bedroom_parquet_floor    on          1
# 1817                           twin_bed    on          1

# %%
grps = facility["facility_sub_grp"]
grps
# Out:
# id_property
# 1817                        NaN
# 1817     unit_bedroom_equipment
# 1817     unit_bedroom_equipment
# 1817     unit_bedroom_equipment
# 1817     unit_bedroom_equipment
#                   ...
# 10647                rdsg_kopno
# 10647                 rdsg_more
# 10647                 rdsg_zrak
# 10647             room_buliding
# 10647             room_buliding
# Name: facility_sub_grp, Length: 211171, dtype: object

# %%
stupci = []
infile = open('gen_data/prazni_stupci_ls.txt','r')
for line in infile:
    stupci.append(line.strip())
stupci
# Out:
# ['air_condition',
#  'description_about_property_short',
#  'parties_allowed',
#  'kids_allowed',
#  'key_pickup_address_client_id',
#  'free_cancelation_last_day',
#  'in_parking_place',
#  'use_grill',
#  'center',
#  'dis_park',
#  'sea',
#  'dis_hospital',
#  'dis_police',
#  'bus',
#  'public_transport',
#  'dis_taxi',
#  'airport',
#  'property_final_cleaning',
#  'property_bed_linen',
#  'property_bed_linen_change',
#  'property_towels',
#  'property_towels_change',
#  'property_towels_set',
#  'property_kitchen_cloths',
#  'property_electrical_energy',
#  'property_water_supply_charge',
#  'meals_in_property',
#  'distance_lake',
#  'fishing',
#  'bar',
#  'casino',
#  'disco',
#  'night_bar',
#  'electricity_network_220',
#  'water_supply',
#  'hot_water_boiler_electric',
#  'property_internet_paidorfree',
#  'property_internet_connectiontype',
#  'property_parking_paidorfree',
#  'property_parking_reservation',
#  'pets_allowed',
#  'pets_charges_yes_no',
#  'owner_in_house',
#  'special_summer',
#  'special_family',
#  'language_hr',
#  'view_sea',
#  'beach_bar',
#  'water_sports',
#  'diving',
#  'water_skiing',
#  'beach_concrete',
#  'beach',
#  'beach_sandy',
#  'beach_shingle',
#  'kiosk',
#  'supermarket',
#  'souvenirshop',
#  'grocery_shop',
#  'green_market',
#  'bank',
#  'atm',
#  'exchange',
#  'post',
#  'restaurant',
#  'public_phone',
#  'payparking',
#  'bike_rent',
#  'sport_equipment_rent',
#  'basketball',
#  'mini_golf',
#  'soccer',
#  'pintball',
#  'paragliding',
#  'table_tennis',
#  'tennis',
#  'distance_stadium',
#  'distance_body_water',
#  'highway',
#  'train',
#  'distance_ferryboat',
#  'property_pets_yes_no_7',
#  'property_pets_over_7',
#  'language_de',
#  'boathire',
#  'beach_rock',
#  'hairdresser',
#  'beauty_salon',
#  'fitness',
#  'massage',
#  'medical_help',
#  'beach_volleyball',
#  'outside_area_completely_enclosed',
#  'language_en',
#  'language_it',
#  'language_si',
#  'location_center_wide',
#  'year_built',
#  'year_rent_start',
#  'year_renovated',
#  'number_units',
#  'distance_moorage',
#  'billiard',
#  'horse_riding',
#  'mini_soccer',
#  'walking_routes',
#  'squash',
#  'playground',
#  'view_street_quiet',
#  'internet_caffe',
#  'location_sea',
#  'badminton',
#  'distance_football_table',
#  'photocopy',
#  'laundry',
#  'pool_bar',
#  'smoking_allowed',
#  'quiet_hours_set',
#  'volleyball',
#  'parking',
#  'view_forest',
#  'paying_cash',
#  'free_cancelation_3_days',
#  'harbour',
#  'pool_public',
#  'hunting',
#  'bike_routes',
#  'beach_grass',
#  'laundry_self_service',
#  'aerobic',
#  'quiet_hours_start_time',
#  'quiet_hours_end_time',
#  'distance_children_beach',
#  'conference_room',
#  'lobby_bar',
#  'dry_cleaning',
#  'distance_river',
#  'pool_length',
#  'wellness',
#  'pool_width',
#  'language_cz',
#  'meeting_room',
#  'birdwatching',
#  'distance_jetski',
#  'pool_max_depth',
#  'paying_amex',
#  'paying_master',
#  'paying_visa',
#  'paying_maestro',
#  'card_payment',
#  'language_sk']

# %%
"""ls=[]
for i in stupci:
    try:
        units[i].loc[facility[facility["facility_code"]==i]["id_property"].tolist()] = 
    except:
        ls.append(i)"""
# Out:
# 'ls=[]\nfor i in stupci:\n    try:\n        units[i].loc[facility[facility["facility_code"]==i]["id_property"].tolist()] = \n    except:\n        ls.append(i)'

# %%
facility[facility["facility_code"]=="air_condition"]["id_property"]
# Out:
# id_property
# 1817      1817
# 1817      1817
# 1817      1817
# 1817      1817
# 1818      1818
#          ...
# 10599    10599
# 10599    10599
# 10599    10599
# 10601    10601
# 10601    10601
# Name: id_property, Length: 3662, dtype: int64

# %%
"""for i in stupci:
    stupac = units[i]
    for pr in units["id_property"]:
        facility[facility["id_property"]==pr]"""
# Out:
# 'for i in stupci:\n    stupac = units[i]\n    for pr in units["id_property"]:\n        facility[facility["id_property"]==pr]'

# %%
units= units.set_index(units["id_property"])
units.head(3)
# Out:
#                 id  id_property  category   area  floor  beds_basic  \
# id_property
# 10043        24588        10043         3  100.0      2           4
# 10043        24589        10043         3  100.0      1           4
# 10043        24590        10043         3  100.0      0           4
#
#              beds_additional  garden  twin_bed  unit_wardrobe_closet  ...  \
# id_property                                                           ...
# 10043                      2       1         1                     1  ...
# 10043                      2       1         1                     1  ...
# 10043                      0       1         1                     1  ...
#
#              mosquito_net  paying_amex  paying_master  paying_visa  \
# id_property
# 10043                   0            0              0            0
# 10043                   0            0              0            0
# 10043                   0            0              0            0
#
#              paying_maestro  card_payment  language_sk  \
# id_property
# 10043                     0             0            0
# 10043                     0             0            0
# 10043                     0             0            0
#
#              property_internet_location  location_turistcomplex  \
# id_property
# 10043                                 0                       0
# 10043                                 0                       0
# 10043                                 0                       0
#
#              in_food_local_speciality
# id_property
# 10043                               0
# 10043                               0
# 10043                               0
#
# [3 rows x 391 columns]

# %%
units["air_condition"]
# Out:
# id_property
# 10043    0
# 10043    0
# 10043    0
# 10046    0
# 9098     0
#         ..
# 10032    0
# 10033    0
# 10034    0
# 10035    0
# 10039    0
# Name: air_condition, Length: 1851, dtype: int64

# %%
facility[(facility["id_property"]==1817) & (facility["id_property_unit"]==0) & (facility["facility_code"]=="tennis")].dropna(subset = ["facility_sub_grp","new_values"])
# Out:
#              id_property_unit  id_property facility_sub_grp facility_code  \
# id_property
# 1817                        0         1817            sport        tennis
#
#             value new_values
# id_property
# 1817          0.5        0.5

# %%
# Out:
#              id_property_unit  id_property facility_sub_grp facility_code  \
# id_property
# 1817                        0         1817              NaN        garden
# 1817                        0         1817         backyard        garden
# 1820                        0         1820         backyard        garden
# 1829                        0         1829              NaN        garden
# 1829                        0         1829         backyard        garden
# ...                       ...          ...              ...           ...
# 10441                       0        10441         backyard        garden
# 10443                       0        10443         backyard        garden
# 10444                       0        10444         backyard        garden
# 10445                       0        10445         backyard        garden
# 10447                       0        10447         backyard        garden
#
#             value new_values
# id_property
# 1817           on          1
# 1817           on          1
# 1820           on          1
# 1829          off         -1
# 1829           on          1
# ...           ...        ...
# 10441          on          1
# 10443          on          1
# 10444          on          1
# 10445          on          1
# 10447          on          1
#
# [511 rows x 6 columns]

# %%
facility= facility.set_index(facility["id_property"])
facility.head(3)
# Out:
#              id_property_unit  id_property        facility_sub_grp  \
# id_property
# 1817                        0         1817                     NaN
# 1817                     3623         1817  unit_bedroom_equipment
# 1817                     3623         1817  unit_bedroom_equipment
#
#                     facility_code value new_values
# id_property
# 1817                       garden    on          1
# 1817                     twin_bed    on          1
# 1817         unit_wardrobe_closet    on          1

# %%
facility.loc[((facility["id_property"]==1817) & (facility["facility_code"]=="tennis")),"new_values"][1817]
# Out:
# '0.5'

# %%
units.loc[1817]

for i in units.loc[10043]["id"]:
    print(i)
# Out:
# 24588
# 24589
# 24590

# %%
units[units["id"]==3623]
# Out:
#                id  id_property  category   area  floor  beds_basic  \
# id_property
# 1817         3623         1817         3  100.0      1           4
#
#              beds_additional  garden  twin_bed  unit_wardrobe_closet  ...  \
# id_property                                                           ...
# 1817                       0       1         1                     1  ...
#
#              mosquito_net  paying_amex  paying_master  paying_visa  \
# id_property
# 1817                    0            0              0            0
#
#              paying_maestro  card_payment  language_sk  \
# id_property
# 1817                      0             0            0
#
#              property_internet_location  location_turistcomplex  \
# id_property
# 1817                                  0                       0
#
#              in_food_local_speciality
# id_property
# 1817                                0
#
# [1 rows x 391 columns]

# %%
units = units.set_index(units["id"])
units.head(3)
# Out:
#           id  id_property  category   area  floor  beds_basic  \
# id
# 24588  24588        10043         3  100.0      2           4
# 24589  24589        10043         3  100.0      1           4
# 24590  24590        10043         3  100.0      0           4
#
#        beds_additional  garden  twin_bed  unit_wardrobe_closet  ...  \
# id                                                              ...
# 24588                2       1         1                     1  ...
# 24589                2       1         1                     1  ...
# 24590                0       1         1                     1  ...
#
#        mosquito_net  paying_amex  paying_master  paying_visa  paying_maestro  \
# id
# 24588             0            0              0            0               0
# 24589             0            0              0            0               0
# 24590             0            0              0            0               0
#
#        card_payment  language_sk  property_internet_location  \
# id
# 24588             0            0                           0
# 24589             0            0                           0
# 24590             0            0                           0
#
#        location_turistcomplex  in_food_local_speciality
# id
# 24588                       0                         0
# 24589                       0                         0
# 24590                       0                         0
#
# [3 rows x 391 columns]

# %%
solounit = []
ls=[]

for pr in units["id_property"].unique():
    try:
        for unit in units[units["id_property"]==pr]["id"]:
            try:
                for stupac in stupci:
                    if float(facility[(facility["id_property"]==pr) & (facility["facility_code"]==stupac)]["new_values"][pr]) != 0:
                        units.loc[unit,stupac] = float(facility.loc[(facility["id_property"]==pr) & (facility["facility_code"]==stupac),["new_values"]][pr])
            except:
                solounit.append(stupac)
    except:
        print(pr)

# %%
len(solounit)
# Out:
# 1851

# %%
units.columns
prazni=[]
rijeseni=[]
for i in units.columns:
    if (units[i]==0).all():
        prazni.append(i)
    else:
        rijeseni.append(i)
print("prazni: ",len(prazni))
print("rijeseni: ",len(rijeseni))
print(len(prazni)+len(rijeseni))
print(len(units.columns))
# Out:
# prazni:  151
# rijeseni:  240
# 391
# 391

# %%
units[["id","id_property", "category", "area", "floor", "beds_basic" ,"beds_additional",'internet-paidorfree', 'internet-connectiontype', 'internet-location']].head(3)
# Out:
#           id  id_property  category   area  floor  beds_basic  \
# id
# 24588  24588        10043         3  100.0      2           4
# 24589  24589        10043         3  100.0      1           4
# 24590  24590        10043         3  100.0      0           4
#
#        beds_additional  internet-paidorfree  internet-connectiontype  \
# id
# 24588                2                    1                        1
# 24589                2                    1                        1
# 24590                0                    1                        1
#
#        internet-location
# id
# 24588                  1
# 24589                  1
# 24590                  1

# %%
stupci_set = set(stupci)
presj = stupci_set.intersection(prazni)
print(presj)
# Out:
# {'paying_cash', 'property_pets_over_7', 'owner_in_house', 'airport', 'payparking', 'property_towels_change', 'quiet_hours_end_time', 'dis_hospital', 'smoking_allowed', 'distance_jetski', 'water_sports', 'pets_charges_yes_no', 'language_hr', 'playground', 'dis_park', 'walking_routes', 'beach_volleyball', 'supermarket', 'bank', 'language_en', 'property_bed_linen_change', 'pool_length', 'pool_bar', 'property_water_supply_charge', 'distance_moorage', 'outside_area_completely_enclosed', 'beach_grass', 'sea', 'night_bar', 'distance_stadium', 'center', 'special_family', 'pool_public', 'mini_soccer', 'quiet_hours_start_time', 'view_sea', 'hairdresser', 'year_rent_start', 'green_market', 'dry_cleaning', 'bike_rent', 'distance_river', 'badminton', 'water_supply', 'distance_lake', 'internet_caffe', 'highway', 'atm', 'air_condition', 'property_final_cleaning', 'property_bed_linen', 'language_cz', 'dis_taxi', 'pool_width', 'bike_routes', 'distance_body_water', 'post', 'billiard', 'hot_water_boiler_electric', 'free_cancelation_3_days', 'aerobic', 'train', 'beauty_salon', 'distance_football_table', 'boathire', 'harbour', 'table_tennis', 'meals_in_property', 'free_cancelation_last_day', 'beach', 'language_de', 'grocery_shop', 'laundry', 'property_electrical_energy', 'lobby_bar', 'soccer', 'quiet_hours_set', 'meeting_room', 'medical_help', 'parties_allowed', 'birdwatching', 'language_si', 'year_built', 'fishing', 'location_center_wide', 'horse_riding', 'property_kitchen_cloths', 'property_parking_reservation', 'fitness', 'paying_visa', 'property_towels', 'beach_shingle', 'sport_equipment_rent', 'public_transport', 'massage', 'paying_amex', 'laundry_self_service', 'property_parking_paidorfree', 'paragliding', 'property_towels_set', 'number_units', 'conference_room', 'distance_children_beach', 'property_pets_yes_no_7', 'paying_master', 'bar', 'bus', 'language_sk', 'language_it', 'card_payment', 'property_internet_connectiontype', 'kiosk', 'diving', 'casino', 'view_street_quiet', 'beach_bar', 'squash', 'beach_concrete', 'dis_police', 'parking', 'beach_sandy', 'special_summer', 'basketball', 'electricity_network_220', 'description_about_property_short', 'pets_allowed', 'souvenirshop', 'use_grill', 'key_pickup_address_client_id', 'mini_golf', 'photocopy', 'exchange', 'restaurant', 'in_parking_place', 'tennis', 'hunting', 'water_skiing', 'view_forest', 'pool_max_depth', 'year_renovated', 'pintball', 'public_phone', 'beach_rock', 'volleyball', 'property_internet_paidorfree', 'kids_allowed', 'disco', 'wellness', 'distance_ferryboat', 'location_sea', 'paying_maestro'}

# %%
print(rijeseni)
# Out:
# ['id', 'id_property', 'category', 'area', 'floor', 'beds_basic', 'beds_additional', 'garden', 'twin_bed', 'unit_wardrobe_closet', 'unit_bedroom_parquet_floor', 'refrigerator', 'dishes', 'oven_pu', 'freezing_compartment', 'dishwasher', 'microwave', 'toaster', 'tea', 'coffee', 'shower', 'unit_wc', 'washbasin', 'unit_bathtub ', 'stove', 'balcony', 'shared_barbecue', 'unit_living_aircondition', 'unit_living_parquet_floor', 'unit_big_sofa', 'unit_living_sat_tv', 'washing_machine', 'sattv', 'internet_wireless', 'un_view_sea', 'terrace', 'unit_living_terrace_exit', 'unit_three_seater', 'unit_armchair', 'use_property_check_in_out', 'description_about_property_frontname', 'description_about_property_long', 'description_unit_frontname', 'description_unit_short', 'description_unit_long', 'heating1', 'deposit_obligatory', 'final_cleaning', 'bed_linen', 'bed_linen_change', 'towels', 'towels_change', 'towels_set', 'kitchen_cloths', 'electrical_energy', 'gas_supply', 'water_supply_charge', 'internet-paidorfree', 'internet-connectiontype', 'internet-location', 'parking-paidorfree', 'parking-privateorpublic', 'parking-location', 'pets', 'unit_floor', 'private_entrance', 'dostupnost_inv_kolica', 'children_ok', 'InformArrivalTime', 'key_pickup', 'property_deposit_obligatory', 'property_gas_supply', 'property_heating1', 'breakfast_in_property', 'lunch_in_property', 'dinner_in_property', 'distance_going_out', 'service_bed_only', 'room_terrace', 'cooking_electric', 'detached', 'outside_shower', 'outdoor_dining_area', 'unit_trash_cans', 'grilling_not_allowed', 'pets_yes_no_7', 'pets_over_7', 'smoking', 'extra_beds_available', 'use_kitchen', 'service_daily_stay', 'heating', 'zajednicka_terasa', 'unit_bedroom_sat_tv', 'unit_living_ceramic_floor', 'unit_two_seater', 'un_view_garden', 'special_all_year', 'view_garden', 'description_about_neighborhood', 'description_about_host', 'entire_property_on_ground_floor', 'in_garden_forniture', 'entertainment', 'music_instruments', 'piano', 'in_pool_open_normalwater_noheat', 'in_boat_included', 'elevator', 'semi_detached', 'un_view_street_quiet', 'large_double_bed', 'location_edgewood', 'location_ski', 'special_noyouthgroups', 'special_agroturism', 'partygames', 'unit_bidet', 'safe', 'freezer', 'dining_table_4_persons', 'chairs', 'dinner_set', 'in_garage', 'pool_kids', 'tree_house', 'timber_house', 'windmill', 'cave_dwelling', 'roof_terrace', 'fish_gutting_point', 'grass_roof', 'no_group_bookings', 'whirlpool', 'tv', 'clothesdryer', 'cooking_highchair', 'fireplace', 'hairdryer', 'music', 'mini_oven', 'under_floor_heating', 'veranda', 'dry_toilet', 'dvd', 'loggia', 'billard', 'gamesconsole', 'iron', 'vaccumcleaner', 'conservatory', 'in_billiard', 'un_view_pool', 'outdoor_security_camera', 'tv_room', 'special_pets', 'un_view_street_busy', 'view_street_busy', 'property_beach', 'un_view_seaside', 'cooking_gas', 'un_whirlpool', 'in_whirlpool', 'un_view_back_building', 'dining_table_2_persons', 'dining_table_3_persons', 'view_back_building', 'private_barbecue', 'flat_tv', 'private_pool', 'un_view_mountain', 'un_view_forest', 'location_village', 'view_mountain', 'separate_toilet', 'childrens_cribs', 'dining_table_6_persons', 'desk', 'special_health_rehabilitation', 'special_children', 'in_pool_open_normalwater_heating', 'pool_outdoor', 'oven', 'bike_included', 'location_beachfront', 'location_away', 'in_ventilator', 'in_extra_bed', 'un_view_center', 'location_center', 'view_center', 'in_sauna', 'unit_hypoallergenic_pillow', 'toilet_paper', 'radio', 'in_bike_rent', 'special_health_prevention', 'in_children_playground', 'internet_network', 'in_tennis', 'GuestIdentification', 'in_table_football', 'in_dart', 'un_view_lake', 'view_lake', 'location_outside', 'in_table_tennis', 'unit_clothes_rack', 'in_cable_tv', 'un_view_river', 'reception', 'breakfast', 'service_bed_breakfast', 'description_structure_frontname', 'description_structure_short', 'description_structure_long', 'special_bike', 'special_sport', 'un_view_park', 'vie ...

# 9869
# 9873
# 9874
# 9875
# 9876
# 9877
# 9880
# 9882
# 9883
# 3454
# 9892
# 9893
# 9894
# 9895
# 9896
# 9897
# 9900
# 9901
# 9902
# 9903
# 9904
# 9905
# 9906
# 9909
# 9911
# 9912
# 9916
# 9917
# 9918
# 9920
# 9921
# 9922
# 9924
# 9925
# 9926
# 9928
# 9935
# 9937
# 9940
# 9941
# 9942
# 9943
# 9944
# 9945
# 9946
# 9947
# 9948
# 9949
# 9950
# 9951
# 9955
# 9956
# 9957
# 9958
# 9960
# 9963
# 9966
# 9967
# 9973
# 9974
# 9975
# 9976
# 9980
# 9981
# 9982
# 9984
# 9985
# 9986
# 3506
# 9990
# 9991
# 9992
# 7098
# 9847
# 9479
# 5661
# 8737
# 8620
# 9486
# 9993
# 9147
# 9994
# 9995
# 9996
# 9999
# 10000
# 10001
# 10002
# 10010
# 10013
# 10014
# 10015
# 10016
# 10019
# 3552
# 3559
# 3564
# 10030
# 10031
# 10032
# 10033
# 10034
# 10035
# 10039

# %%
units[units["id_property"]==10043]
# Out:
#           id  id_property  category   area  floor  beds_basic  \
# id
# 24588  24588        10043         3  100.0      2           4
# 24589  24589        10043         3  100.0      1           4
# 24590  24590        10043         3  100.0      0           4
#
#        beds_additional  garden  twin_bed  unit_wardrobe_closet  ...  \
# id                                                              ...
# 24588                2       1         1                     1  ...
# 24589                2       1         1                     1  ...
# 24590                0       1         1                     1  ...
#
#        mosquito_net  paying_amex  paying_master  paying_visa  paying_maestro  \
# id
# 24588             0            0              0            0               0
# 24589             0            0              0            0               0
# 24590             0            0              0            0               0
#
#        card_payment  language_sk  property_internet_location  \
# id
# 24588             0            0                           0
# 24589             0            0                           0
# 24590             0            0                           0
#
#        location_turistcomplex  in_food_local_speciality
# id
# 24588                       0                         0
# 24589                       0                         0
# 24590                       0                         0
#
# [3 rows x 391 columns]

# %%
#units.to_csv("gen_data/rijeseni-249.csv")

# %%
full_units = units.drop(prazni,axis=1)
full_units.shape
# Out:
# (1851, 240)

# %%
stats = full_units.describe()
#stats.to_csv("gen_data/stat.csv")

# %%
full_units.head(3)
# Out:
#           id  id_property  category   area  floor  beds_basic  \
# id
# 24588  24588        10043         3  100.0      2           4
# 24589  24589        10043         3  100.0      1           4
# 24590  24590        10043         3  100.0      0           4
#
#        beds_additional  garden  twin_bed  unit_wardrobe_closet  ...  \
# id                                                              ...
# 24588                2       1         1                     1  ...
# 24589                2       1         1                     1  ...
# 24590                0       1         1                     1  ...
#
#        hot_water_supply  no_smoking_rooms  in_mini_soccer  special_business  \
# id
# 24588                 0                 0               0                 0
# 24589                 0                 0               0                 0
# 24590                 0                 0               0                 0
#
#        special_groups  unit_bedroom_mosquito_net  mosquito_net  \
# id
# 24588               0                          0             0
# 24589               0                          0             0
# 24590               0                          0             0
#
#        property_internet_location  location_turistcomplex  \
# id
# 24588                           0                       0
# 24589                           0                       0
# 24590                           0                       0
#
#        in_food_local_speciality
# id
# 24588                         0
# 24589                         0
# 24590                         0
#
# [3 rows x 240 columns]

# %%
facility = facility.set_index(facility["id_property_unit"])

# %%
desc = full_units.describe()
desc
# Out:
#                  id   id_property     category         area        floor  \
# count   1851.000000   1851.000000  1851.000000  1851.000000  1851.000000
# mean   20468.457050   7877.850351     3.057266    58.539438     0.525662
# std     6542.573553   2789.882301     0.525012    35.565741     0.831648
# min     3623.000000   1817.000000     0.000000     0.000000    -1.000000
# 25%    18657.500000   6440.000000     3.000000    35.000000     0.000000
# 50%    23375.000000   9044.000000     3.000000    50.000000     0.000000
# 75%    24874.500000  10129.000000     3.000000    70.000000     1.000000
# max    25832.000000  10679.000000     5.000000   420.000000     4.000000
#
#         beds_basic  beds_additional       garden     twin_bed  \
# count  1851.000000      1851.000000  1851.000000  1851.000000
# mean      3.507293         0.940032     0.397083     0.678552
# std       1.756017         0.914255     0.489426     0.467158
# min       0.000000         0.000000     0.000000     0.000000
# 25%       2.000000         0.000000     0.000000     0.000000
# 50%       4.000000         1.000000     0.000000     1.000000
# 75%       4.000000         2.000000     1.000000     1.000000
# max      14.000000         5.000000     1.000000     1.000000
#
#        unit_wardrobe_closet  ...  hot_water_supply  no_smoking_rooms  \
# count           1851.000000  ...       1851.000000       1851.000000
# mean               0.796867  ...          0.001621          0.002701
# std                0.402440  ...          0.040237          0.051917
# min                0.000000  ...          0.000000          0.000000
# 25%                1.000000  ...          0.000000          0.000000
# 50%                1.000000  ...          0.000000          0.000000
# 75%                1.000000  ...          0.000000          0.000000
# max                1.000000  ...          1.000000          1.000000
#
#        in_mini_soccer  special_business  special_groups  \
# count     1851.000000       1851.000000     1851.000000
# mean         0.000540          0.001080        0.000540
# std          0.023243          0.032862        0.023243
# min          0.000000          0.000000        0.000000
# 25%          0.000000          0.000000        0.000000
# 50%          0.000000          0.000000        0.000000
# 75%          0.000000          0.000000        0.000000
# max          1.000000          1.000000        1.000000
#
#        unit_bedroom_mosquito_net  mosquito_net  property_internet_location  \
# count                1851.000000   1851.000000                 1851.000000
# mean                    0.002161      0.001621                    0.000540
# std                     0.046449      0.040237                    0.023243
# min                     0.000000      0.000000                    0.000000
# 25%                     0.000000      0.000000                    0.000000
# 50%                     0.000000      0.000000                    0.000000
# 75%                     0.000000      0.000000                    0.000000
# max                     1.000000      1.000000                    1.000000
#
#        location_turistcomplex  in_food_local_speciality
# count             1851.000000               1851.000000
# mean                 0.010805                  0.002161
# std                  0.103412                  0.046449
# min                  0.000000                  0.000000
# 25%                  0.000000                  0.000000
# 50%                  0.000000                  0.000000
# 75%                  0.000000                  0.000000
# max                  1.000000                  1.000000
#
# [8 rows x 240 columns]

# %%
# Out:
# id                            0
# id_property                   0
# category                      0
# area                          0
# floor                         0
#                              ..
# unit_bedroom_mosquito_net     0
# mosquito_net                  0
# property_internet_location    0
# location_turistcomplex        0
# in_food_local_speciality      0
# Length: 240, dtype: int64

# %%
full_columns = full_units.columns

# %%
# Out:
#           id  id_property  category   area  floor  beds_basic  \
# id
# 24588  24588        10043         3  100.0      2           4
# 24589  24589        10043         3  100.0      1           4
# 24590  24590        10043         3  100.0      0           4
# 24593  24593        10046         3   53.0      0           4
# 24594  24594         9098         3   65.0      0           4
# ...      ...          ...       ...    ...    ...         ...
# 24569  24569        10032         3   95.0      2           6
# 24570  24570        10033         3   45.0      1           2
# 24571  24571        10034         5  150.0      0           6
# 24572  24572        10035         5  150.0      0           6
# 24575  24575        10039         4  178.0      0           6
#
#        beds_additional  garden  twin_bed  unit_wardrobe_closet  ...  \
# id                                                              ...
# 24588                2       1         1                     1  ...
# 24589                2       1         1                     1  ...
# 24590                0       1         1                     1  ...
# 24593                0       1         1                     1  ...
# 24594                1       1         1                     1  ...
# ...                ...     ...       ...                   ...  ...
# 24569                0       0         0                     0  ...
# 24570                2       0         1                     1  ...
# 24571                0       1         1                     1  ...
# 24572                0       1         1                     1  ...
# 24575                0       1         1                     1  ...
#
#        hot_water_supply  no_smoking_rooms  in_mini_soccer  special_business  \
# id
# 24588                 0                 0               0                 0
# 24589                 0                 0               0                 0
# 24590                 0                 0               0                 0
# 24593                 0                 0               0                 0
# 24594                 0                 0               0                 0
# ...                 ...               ...             ...               ...
# 24569                 0                 0               0                 0
# 24570                 0                 0               0                 0
# 24571                 0                 0               0                 0
# 24572                 0                 0               0                 0
# 24575                 0                 0               0                 0
#
#        special_groups  unit_bedroom_mosquito_net  mosquito_net  \
# id
# 24588               0                          0             0
# 24589               0                          0             0
# 24590               0                          0             0
# 24593               0                          0             0
# 24594               0                          0             0
# ...               ...                        ...           ...
# 24569               0                          0             0
# 24570               0                          0             0
# 24571               0                          0             0
# 24572               0                          0             0
# 24575               0                          0             0
#
#        property_internet_location  location_turistcomplex  \
# id
# 24588                           0                       0
# 24589                           0                       0
# 24590                           0                       0
# 24593                           0                       0
# 24594                           0                       0
# ...                           ...                     ...
# 24569                           0                       0
# 24570                           0                       0
# 24571                           0                       0
# 24572                           0                       0
# 24575                           0                       0
#
#        in_food_local_speciality
# id
# 24588                         0
# 24589                         0
# 24590                         0
# 24593                         0
# 24594                         0
# ...                         ...
# 24569                         0
# 24570                         0
# 24571                         0
# 24572                         0
# 24575                         0
#
# [1851 rows x 240 columns]

# %%
sub_grp = facility[["facility_sub_grp","facility_code"]]
sub_grp.reset_index(inplace=True)
sub_grp.head()
fgrp = sub_grp["facility_sub_grp"].unique()
fgrp
fcodes = sub_grp["facility_code"].unique()
#print(fcodes)
facility[facility["facility_sub_grp"]=="kitchen"]["facility_code"].unique()
# Out:
# array(['refrigerator', 'dishes', 'oven_pu', 'freezing_compartment',
#        'dishwasher', 'microwave', 'toaster', 'tea', 'coffee', 'stove',
#        'cooking_electric', 'shared_barbecue', 'cooking_gas',
#        'grilling_not_allowed', 'private_barbecue', 'freezer', 'mini_oven',
#        'cooking_highchair'], dtype=object)

# %%
""" df = pd.DataFrame(columns=['lib', 'qty1', 'qty2'])
>>> for i in range(5):
>>>     df.loc[i] = ['name' + str(i)] + list(randint(10, size=2))"""


no_grp=[]
grp_df = pd.DataFrame(columns = ["facility_sub_grp", "facility_code"])
for index,i in enumerate(fcodes):
    try:
        grp_df.loc[index] = [facility[facility["facility_code"]==i]["facility_sub_grp"].dropna().unique().tolist()[0],i]
    except:
        no_grp.append(i)
    
grp_df.shape
# Out:
# (341, 2)

# %%
grp_df.head(50)
# Out:
#              facility_sub_grp               facility_code
# 0                    backyard                      garden
# 1      unit_bedroom_equipment                    twin_bed
# 2      unit_bedroom_equipment        unit_wardrobe_closet
# 3      unit_bedroom_equipment  unit_bedroom_parquet_floor
# 4                     kitchen                refrigerator
# 5                     kitchen                      dishes
# 6                     kitchen                     oven_pu
# 7                     kitchen        freezing_compartment
# 8                     kitchen                  dishwasher
# 9                     kitchen                   microwave
# 10                    kitchen                     toaster
# 11                    kitchen                         tea
# 12                    kitchen                      coffee
# 13    unit_bathroom_equipment                      shower
# 14    unit_bathroom_equipment                     unit_wc
# 15    unit_bathroom_equipment                   washbasin
# 16    unit_bathroom_equipment               unit_bathtub
# 17                    kitchen                       stove
# 18              room_buliding                     balcony
# 19             unit_equipment               air_condition
# 20                    kitchen             shared_barbecue
# 21      unit_living_equipment    unit_living_aircondition
# 22      unit_living_equipment   unit_living_parquet_floor
# 23      unit_living_equipment               unit_big_sofa
# 24      unit_living_equipment          unit_living_sat_tv
# 25    unit_bathroom_equipment             washing_machine
# 28  unit_pogled_mikrolokacija                 un_view_sea
# 29         property_equipment                     terrace
# 30      unit_living_equipment    unit_living_terrace_exit
# 31      unit_living_equipment           unit_three_seater
# 32      unit_living_equipment               unit_armchair
# 44         unit_extras_others                    heating1
# 45         unit_extras_others          deposit_obligatory
# 46         unit_extras_others              final_cleaning
# 47             unit_bed_linen                   bed_linen
# 48             unit_bed_linen            bed_linen_change
# 49                unit_towels                      towels
# 50                unit_towels               towels_change
# 51                unit_towels                  towels_set
# 52                unit_cloths              kitchen_cloths
# 53   sg_water_gas_electricity           electrical_energy
# 54   sg_water_gas_electricity                  gas_supply
# 55   sg_water_gas_electricity         water_supply_charge
# 56             sg_house_rules             parties_allowed
# 57                sg_internet         internet-paidorfree
# 58                sg_internet     internet-connectiontype
# 59                sg_internet           internet-location
# 60                 sg_parking          parking-paidorfree
# 61                 sg_parking     parking-privateorpublic
# 62                 sg_parking            parking-location

# %%
#grp_df.to_csv("gen_data/facility_togrp.csv")

# %%
#78 grupa
grp_df["facility_sub_grp"].unique()
# Out:
# array(['backyard', 'unit_bedroom_equipment', 'kitchen',
#        'unit_bathroom_equipment', 'room_buliding', 'unit_equipment',
#        'unit_living_equipment', 'unit_pogled_mikrolokacija',
#        'property_equipment', 'unit_extras_others', 'unit_bed_linen',
#        'unit_towels', 'unit_cloths', 'sg_water_gas_electricity',
#        'sg_house_rules', 'sg_internet', 'sg_parking', 'sg_pets',
#        'sg_kids_policy', 'unit_building_facilities',
#        'unit_maindata_others', 'sq_mandatory_at_reservation',
#        'policies_cancelation', 'sg_free_cancelation_ar', 'parking_garage',
#        'disg_common', 'disg_transport', 'property_final_cleaning',
#        'property_security_deposit', 'property_bed_linen',
#        'property_towels', 'property_kitchen_cloth', 'property_sg_gas',
#        'property_sg_electricity', 'property_sg_water',
#        'property_extras_others', 'sg_extra_service_main',
#        'sg_property_food_beverages_main', 'sg_property_food_bev_meals',
#        'hoby', 'leisure', 'sg_electricity', 'sg_water', 'sg_hot_water',
#        'property_sg_internet', 'property_sg_parking', 'property_sg_pets',
#        'main', 'sg_service', 'sg_special', 'sg_language', 'sg_view',
#        'disg_sea', 'disg_beaches', 'disg_shops', 'disg_services',
#        'disg_public_parking', 'sport', 'rdsg_food', 'rdsg_shop',
#        'rdsg_nature', 'rdsg_culture', 'rdsg_kopno', 'rdsg_zrak',
#        'rdsg_more', 'property_city_tax', 'health',
#        'unit_gradevinske_znacajke', 'sg_location', 'spa_pool',
#        'sg_reservation_cond', 'children', 'sport_zabava', 'sg_paying',
#        'public_pools', 'sq_guarantee_payment', 'snow', 'sg_food'],
#       dtype=object)

# %%
units.head()
# Out:
#           id  id_property  category   area  floor  beds_basic  \
# id
# 24588  24588        10043         3  100.0      2           4
# 24589  24589        10043         3  100.0      1           4
# 24590  24590        10043         3  100.0      0           4
# 24593  24593        10046         3   53.0      0           4
# 24594  24594         9098         3   65.0      0           4
#
#        beds_additional  garden  twin_bed  unit_wardrobe_closet  ...  \
# id                                                              ...
# 24588                2       1         1                     1  ...
# 24589                2       1         1                     1  ...
# 24590                0       1         1                     1  ...
# 24593                0       1         1                     1  ...
# 24594                1       1         1                     1  ...
#
#        mosquito_net  paying_amex  paying_master  paying_visa  paying_maestro  \
# id
# 24588             0            0              0            0               0
# 24589             0            0              0            0               0
# 24590             0            0              0            0               0
# 24593             0            0              0            0               0
# 24594             0            0              0            0               0
#
#        card_payment  language_sk  property_internet_location  \
# id
# 24588             0            0                           0
# 24589             0            0                           0
# 24590             0            0                           0
# 24593             0            0                           0
# 24594             0            0                           0
#
#        location_turistcomplex  in_food_local_speciality
# id
# 24588                       0                         0
# 24589                       0                         0
# 24590                       0                         0
# 24593                       0                         0
# 24594                       0                         0
#
# [5 rows x 391 columns]

# %%
units_grp = units[["id","id_property", "category", "area", "floor", "beds_basic" ,"beds_additional"]]
units_grp
# Out:
#           id  id_property  category   area  floor  beds_basic  beds_additional
# id
# 24588  24588        10043         3  100.0      2           4                2
# 24589  24589        10043         3  100.0      1           4                2
# 24590  24590        10043         3  100.0      0           4                0
# 24593  24593        10046         3   53.0      0           4                0
# 24594  24594         9098         3   65.0      0           4                1
# ...      ...          ...       ...    ...    ...         ...              ...
# 24569  24569        10032         3   95.0      2           6                0
# 24570  24570        10033         3   45.0      1           2                2
# 24571  24571        10034         5  150.0      0           6                0
# 24572  24572        10035         5  150.0      0           6                0
# 24575  24575        10039         4  178.0      0           6                0
#
# [1851 rows x 7 columns]
