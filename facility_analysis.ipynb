# %%
import numpy as np
import pandas as pd
import matplotlib

facilities = pd.read_csv('data/property_facilities.csv', delimiter=';')
facilities.head(3)
# Out:
# C:\Users\Korisnik\anaconda3\envs\AGprojekt\lib\site-packages\IPython\core\interactiveshell.py:3251: DtypeWarning: Columns (13,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        id  id_company  id_account_client  id_property  id_property_structure  \
# 0  173464           0                  0         1817                      0
# 1  714096           0                  0         1817                      0
# 2  714097           0                  0         1817                      0
#
#    id_property_unit  id_property_unit_room              object  \
# 0                 0                      0            property
# 1              3623                   9911  property_unit_room
# 2              3623                   9911  property_unit_room
#
#   facility_group_code  real_facility_name        facility_sub_grp  \
# 0          char_basic                 NaN                     NaN
# 1        char_general                 NaN  unit_bedroom_equipment
# 2        char_general                 NaN  unit_bedroom_equipment
#
#           facility_code value value_secondary  value_num value_jm  \
# 0                garden    on             NaN        0.0      NaN
# 1              twin_bed    on             NaN        0.0      NaN
# 2  unit_wardrobe_closet    on             NaN        0.0      NaN
#
#    id_client_upisao             datetime
# 0                 0  2018-11-30 10:07:51
# 1                 0  2020-11-03 14:21:38
# 2                 0  2020-11-03 14:21:38

# %%
freq = facilities["facility_sub_grp"].value_counts()
freq.head(50)
freq.to_csv("gen_data/sub_grp_frequency.csv")


freq0 = freq[0:40]
freq1 = freq[40:]
freq.head(5)
# Out:
# disg_services    3953
# disg_beaches     3914
# disg_shops       3565
# disg_sea         3107
# sport            3074
# Name: facility_sub_grp, dtype: int64

# %%
freq0.plot.bar()
# Out:
# <AxesSubplot:>

# %%
freq1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
uniq_fac = pd.read_csv('gen_data/facilities.csv', delimiter=';')
uniq_fac.head()
# Out:
#                             0
# 0                      garden
# 1                    twin_bed
# 2        unit_wardrobe_closet
# 3  unit_bedroom_parquet_floor
# 4                refrigerator

# %%
uniq_fac.shape
# Out:
# (430, 1)

# %%
in_vector = pd.read_csv('data/input_fac.csv', delimiter=';')["facility_inputs"].tolist()


ls=[]
lsprazni=[]
for index,i in enumerate(facilities['facility_code']):
    if i not in in_vector:
        ls.append(index)
print(len(ls))


facilities = facilities.drop(ls)

print(facilities.shape)
print(facilities.head())
# Out:
# 169799
# (41372, 18)
#         id  id_company  id_account_client  id_property  id_property_structure  \
# 0   173464           0                  0         1817                      0
# 38  714291           0                  0         1817                      0
# 61  714340           0                  0         1817                      0
# 62  714341           0                  0         1817                      0
# 90  849458           0                  0         1817                      0
#
#     id_property_unit  id_property_unit_room              object  \
# 0                  0                      0            property
# 38             23113                      0       property_unit
# 61              3623                      0       property_unit
# 62              3623                      0       property_unit
# 90              3623                   9917  property_unit_room
#
#    facility_group_code  real_facility_name facility_sub_grp  facility_code  \
# 0           char_basic                 NaN              NaN         garden
# 38        char_general                 NaN              NaN  air_condition
# 61        char_general                 NaN              NaN        terrace
# 62        char_general                 NaN              NaN  air_condition
# 90        char_general                 NaN   unit_equipment  air_condition
#
#    value value_secondary  value_num value_jm  id_client_upisao  \
# 0     on             NaN        0.0      NaN                 0
# 38    on             NaN        0.0      NaN                 0
# 61    on             NaN        0.0      NaN                 0
# 62    on             NaN        0.0      NaN                 0
# 90    on             NaN        0.0      NaN                 0
#
#                datetime
# 0   2018-11-30 10:07:51
# 38  2020-11-03 14:44:53
# 61  2020-11-03 14:45:22
# 62  2020-11-03 14:45:22
# 90  2021-03-29 09:49:52

# %%
freq2 = facilities["facility_code"].value_counts()
freq2.head(5)
# Out:
# air_condition       3662
# terrace             1416
# grocery_shop        1064
# in_parking_place    1005
# special_summer       987
# Name: facility_code, dtype: int64

# %%
freq2.plot.bar()
# Out:
# <AxesSubplot:>
