# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pylab as plt

# %%
df = pd.read_csv("gen_data/gen2/units_df.csv")
df
# Out:
#          id  id_property  beds_basic  backyard  unit_bedroom_equipment  \
# 0     24588        10043           4  0.449021                1.076279
# 1     24589        10043           4  0.449021                1.076279
# 2     24590        10043           4  0.449021                1.076279
# 3     24593        10046           4  0.449021                0.052836
# 4     24594         9098           4  0.449021                1.738705
# ...     ...          ...         ...       ...                     ...
# 1846  24569        10032           6 -0.985702               -2.514751
# 1847  24570        10033           2 -0.985702                0.052836
# 1848  24571        10034           6  2.037106                1.619756
# 1849  24572        10035           6  2.037106                1.619756
# 1850  24575        10039           6  2.037106                1.076279
#
#        kitchen  unit_bathroom_equipment  room_buliding  unit_equipment  \
# 0     2.243948                 0.106548      -1.014682       -0.270266
# 1     0.275252                 0.949890      -1.014682       -0.270266
# 2     0.871971                -0.727768       1.971703       -0.270266
# 3    -0.047857                -0.727768      -1.014682       -0.270266
# 4     0.079925                 0.106548       1.971703       -0.270266
# ...        ...                      ...            ...             ...
# 1846 -0.360594                 3.271077      -1.014682        3.700064
# 1847 -1.255616                -0.368422       0.487153       -0.270266
# 1848 -2.063006                -1.202737       0.469868       -0.270266
# 1849 -2.063006                -1.202737       0.469868       -0.270266
# 1850 -2.154459                -0.717384       0.469868       -0.270266
#
#       unit_living_equipment  ...  in_cable_tv  un_view_river  breakfast  \
# 0                 -0.484396  ...    -0.046537       -0.02325  -0.052044
# 1                 -0.484396  ...    -0.046537       -0.02325  -0.052044
# 2                  1.912237  ...    -0.046537       -0.02325  -0.052044
# 3                  1.559785  ...    -0.046537       -0.02325  -0.052044
# 4                  2.056771  ...    -0.046537       -0.02325  -0.052044
# ...                     ...  ...          ...            ...        ...
# 1846              -2.613393  ...    -0.046537       -0.02325  -0.052044
# 1847               0.448779  ...    -0.046537       -0.02325  -0.052044
# 1848               1.459655  ...    -0.046537       -0.02325  -0.052044
# 1849               1.324192  ...    -0.046537       -0.02325  -0.052044
# 1850               2.001224  ...    -0.046537       -0.02325  -0.052044
#
#       description_structure_frontname  description_structure_short  \
# 0                           -0.061612                    -0.057027
# 1                           -0.061612                    -0.057027
# 2                           -0.061612                    -0.057027
# 3                           -0.061612                    -0.057027
# 4                           -0.061612                    -0.057027
# ...                               ...                          ...
# 1846                        -0.061612                    -0.057027
# 1847                        -0.061612                    -0.057027
# 1848                        -0.061612                    -0.057027
# 1849                        -0.061612                    -0.057027
# 1850                        -0.061612                    -0.057027
#
#       description_structure_long  un_view_park  minibar  meal_room_only  \
# 0                      -0.052044     -0.032889 -0.02325       -0.032889
# 1                      -0.052044     -0.032889 -0.02325       -0.032889
# 2                      -0.052044     -0.032889 -0.02325       -0.032889
# 3                      -0.052044     -0.032889 -0.02325       -0.032889
# 4                      -0.052044     -0.032889 -0.02325       -0.032889
# ...                          ...           ...      ...             ...
# 1846                   -0.052044     30.405592 -0.02325       -0.032889
# 1847                   -0.052044     -0.032889 -0.02325       -0.032889
# 1848                   -0.052044     -0.032889 -0.02325       -0.032889
# 1849                   -0.052044     -0.032889 -0.02325       -0.032889
# 1850                   -0.052044     -0.032889 -0.02325       -0.032889
#
#       mosquito_net
# 0        -0.040291
# 1        -0.040291
# 2        -0.040291
# 3        -0.040291
# 4        -0.040291
# ...            ...
# 1846     -0.040291
# 1847     -0.040291
# 1848     -0.040291
# 1849     -0.040291
# 1850     -0.040291
#
# [1851 rows x 122 columns]

# %%
df_price = pd.read_csv("gen_data/gen2/Unit_cjenik.csv")
df_price
# Out:
#                                          name       id  id_unit  id_head  \
# 0                 CM (1-4) Najam 1 do 4 osobe  3291688     3623    65610
# 1                 CM (1-4) Najam 1 do 4 osobe  3234811    23113    65611
# 2                 CM (1-4) Najam 1 do 4 osobe  3196314     3624    69418
# 3     CM 4 Najam  objekta - 4 osobe u objektu  3279524     3633    65907
# 4                 CM (1-2) Najam 1 do 2 osobe  3279559     3634    65909
# ...                                       ...      ...      ...      ...
# 1441  CM 3 Najam  objekta - 3 osobe u objektu  3284807    25727    69655
# 1442              CM (1-2) Najam 1 do 2 osobe  3274735    25729    69662
# 1443              CM (1-2) Najam 1 do 2 osobe  3290257    25785    69752
# 1444              CM (1-2) Najam 1 do 2 osobe  3290273    25787    69753
# 1445              CM (1-4) Najam 1 do 4 osobe  3290290    25788    69754
#
#       date_start    date_end  amount
# 0     2022-07-09  2022-08-12   72.00
# 1     2022-07-09  2022-08-12   72.00
# 2     2022-07-30  2022-08-12  151.00
# 3     2022-07-16  2022-08-19   76.49
# 4     2022-07-16  2022-08-19   54.64
# ...          ...         ...     ...
# 1441  2022-07-16  2022-08-19   80.00
# 1442  2022-07-16  2022-08-19   67.00
# 1443  2022-07-16  2022-08-19   55.00
# 1444  2022-07-16  2022-08-19   55.00
# 1445  2022-07-16  2022-08-19   81.00
#
# [1446 rows x 7 columns]

# %% [markdown]
# ## Micanje pologa unita

# %%
df_price.name.unique()
# Out:
# array(['CM (1-4) Najam 1 do 4 osobe',
#        'CM 4 Najam  objekta - 4 osobe u objektu',
#        'CM (1-2) Najam 1 do 2 osobe',
#        'CM 5 Najam  objekta - 5 osoba u objektu',
#        'CM 3 Najam  objekta - 3 osobe u objektu',
#        'CM 8 Najam  objekta - 8 osoba u objektu',
#        'CM (1-8) Najam 1 do 8 osoba',
#        'CM 6 Najam  objekta - 6 osoba u objektu',
#        'CM (1-6) Najam 1 do 6 osoba', 'CM (1-7) Najam 1 do 7 osoba',
#        'CM - Polog pri dolasku', 'CM (1-12) Najam 1 do 12 osoba',
#        'CM 7 Najam  objekta - 7 osoba u objektu',
#        'CM 14 Najam  objekta - 14 osoba u objektu',
#        'CM 9 Najam  objekta - 9 osoba u objektu',
#        'CM (1-5) Najam 1 do 5 osoba', 'CM (1-3) Najam 1 do 3 osobe',
#        'CM 10  Najam  objekta - 10 osoba u objektu',
#        'CM - Dodatak % za kratki boravak 1 - 2 dana (po danu)',
#        'CM (1-10) Najam 1 do 10 osoba',
#        'CM 12 Najam  objekta - 12 osoba u objektu',
#        'CM 13 Najam  objekta - 13 osoba u objektu',
#        'CM (1-14) Najam 1 do 14 osoba'], dtype=object)

# %%
df_price.set_index("id_unit")
# Out:
#                                             name       id  id_head  \
# id_unit
# 3623                 CM (1-4) Najam 1 do 4 osobe  3291688    65610
# 23113                CM (1-4) Najam 1 do 4 osobe  3234811    65611
# 3624                 CM (1-4) Najam 1 do 4 osobe  3196314    69418
# 3633     CM 4 Najam  objekta - 4 osobe u objektu  3279524    65907
# 3634                 CM (1-2) Najam 1 do 2 osobe  3279559    65909
# ...                                          ...      ...      ...
# 25727    CM 3 Najam  objekta - 3 osobe u objektu  3284807    69655
# 25729                CM (1-2) Najam 1 do 2 osobe  3274735    69662
# 25785                CM (1-2) Najam 1 do 2 osobe  3290257    69752
# 25787                CM (1-2) Najam 1 do 2 osobe  3290273    69753
# 25788                CM (1-4) Najam 1 do 4 osobe  3290290    69754
#
#          date_start    date_end  amount
# id_unit
# 3623     2022-07-09  2022-08-12   72.00
# 23113    2022-07-09  2022-08-12   72.00
# 3624     2022-07-30  2022-08-12  151.00
# 3633     2022-07-16  2022-08-19   76.49
# 3634     2022-07-16  2022-08-19   54.64
# ...             ...         ...     ...
# 25727    2022-07-16  2022-08-19   80.00
# 25729    2022-07-16  2022-08-19   67.00
# 25785    2022-07-16  2022-08-19   55.00
# 25787    2022-07-16  2022-08-19   55.00
# 25788    2022-07-16  2022-08-19   81.00
#
# [1446 rows x 6 columns]

# %%
df_price.drop(df_price[df_price['name'] == "CM - Polog pri dolasku"].index, inplace = True)
df_price.drop(df_price[df_price['name'] == "CM - Dodatak % za kratki boravak 1 - 2 dana (po danu)"].index, inplace = True)

# %%
df_price
# Out:
#                                             name       id  id_unit  id_head  \
# id_unit
# 3623                 CM (1-4) Najam 1 do 4 osobe  3291688     3623    65610
# 23113                CM (1-4) Najam 1 do 4 osobe  3234811    23113    65611
# 3624                 CM (1-4) Najam 1 do 4 osobe  3196314     3624    69418
# 3633     CM 4 Najam  objekta - 4 osobe u objektu  3279524     3633    65907
# 3634                 CM (1-2) Najam 1 do 2 osobe  3279559     3634    65909
# ...                                          ...      ...      ...      ...
# 25727    CM 3 Najam  objekta - 3 osobe u objektu  3284807    25727    69655
# 25729                CM (1-2) Najam 1 do 2 osobe  3274735    25729    69662
# 25785                CM (1-2) Najam 1 do 2 osobe  3290257    25785    69752
# 25787                CM (1-2) Najam 1 do 2 osobe  3290273    25787    69753
# 25788                CM (1-4) Najam 1 do 4 osobe  3290290    25788    69754
#
#          date_start    date_end  amount
# id_unit
# 3623     2022-07-09  2022-08-12   72.00
# 23113    2022-07-09  2022-08-12   72.00
# 3624     2022-07-30  2022-08-12  151.00
# 3633     2022-07-16  2022-08-19   76.49
# 3634     2022-07-16  2022-08-19   54.64
# ...             ...         ...     ...
# 25727    2022-07-16  2022-08-19   80.00
# 25729    2022-07-16  2022-08-19   67.00
# 25785    2022-07-16  2022-08-19   55.00
# 25787    2022-07-16  2022-08-19   55.00
# 25788    2022-07-16  2022-08-19   81.00
#
# [1416 rows x 7 columns]

# %% [markdown]
# ### Dobivanje unita s cijenom

# %%
units = pd.Series(list(set(df["id"].tolist()) & set(df_price["id_unit"].tolist())))
units
# Out:
# 0       24588
# 1       24589
# 2       24590
# 3       24593
# 4       24594
#         ...
# 1359     8166
# 1360     8175
# 1361     8176
# 1362    24567
# 1363    24575
# Length: 1364, dtype: int64

# %%
df.set_index(df["id"],inplace=True)

# %%
df_full = df.loc[units]
df_full
# Out:
#           id  id_property  beds_basic  backyard  unit_bedroom_equipment  \
# id
# 24588  24588        10043           4  0.449021                1.076279
# 24589  24589        10043           4  0.449021                1.076279
# 24590  24590        10043           4  0.449021                1.076279
# 24593  24593        10046           4  0.449021                0.052836
# 24594  24594         9098           4  0.449021                1.738705
# ...      ...          ...         ...       ...                     ...
# 8166    8166         3559           6  0.449021                1.980774
# 8175    8175         3564           4 -0.985702                1.076279
# 8176    8176         3564           2 -0.985702                1.076279
# 24567  24567        10030           4  2.037106                1.980774
# 24575  24575        10039           6  2.037106                1.076279
#
#         kitchen  unit_bathroom_equipment  room_buliding  unit_equipment  \
# id
# 24588  2.243948                 0.106548      -1.014682       -0.270266
# 24589  0.275252                 0.949890      -1.014682       -0.270266
# 24590  0.871971                -0.727768       1.971703       -0.270266
# 24593 -0.047857                -0.727768      -1.014682       -0.270266
# 24594  0.079925                 0.106548       1.971703       -0.270266
# ...         ...                      ...            ...             ...
# 8166  -0.559610                 0.949890      -1.014682       -0.270266
# 8175   0.236125                -1.202737      -1.014682       -0.270266
# 8176   6.654588                 0.474920      -1.014682       -0.270266
# 24567 -1.262515                -0.780050      -1.014682       -0.270266
# 24575 -2.154459                -0.717384       0.469868       -0.270266
#
#        unit_living_equipment  ...  in_cable_tv  un_view_river  breakfast  \
# id                            ...
# 24588              -0.484396  ...    -0.046537       -0.02325  -0.052044
# 24589              -0.484396  ...    -0.046537       -0.02325  -0.052044
# 24590               1.912237  ...    -0.046537       -0.02325  -0.052044
# 24593               1.559785  ...    -0.046537       -0.02325  -0.052044
# 24594               2.056771  ...    -0.046537       -0.02325  -0.052044
# ...                      ...  ...          ...            ...        ...
# 8166               -1.617410  ...    -0.046537       -0.02325  -0.052044
# 8175                1.499853  ...    -0.046537       -0.02325  -0.052044
# 8176               -2.613393  ...    -0.046537       -0.02325  -0.052044
# 24567               2.293686  ...    -0.046537       -0.02325  -0.052044
# 24575               2.001224  ...    -0.046537       -0.02325  -0.052044
#
#        description_structure_frontname  description_structure_short  \
# id
# 24588                        -0.061612                    -0.057027
# 24589                        -0.061612                    -0.057027
# 24590                        -0.061612                    -0.057027
# 24593                        -0.061612                    -0.057027
# 24594                        -0.061612                    -0.057027
# ...                                ...                          ...
# 8166                         -0.061612                    -0.057027
# 8175                         -0.061612                    -0.057027
# 8176                         -0.061612                    -0.057027
# 24567                        -0.061612                    -0.057027
# 24575                        -0.061612                    -0.057027
#
#        description_structure_long  un_view_park  minibar  meal_room_only  \
# id
# 24588                   -0.052044     -0.032889 -0.02325       -0.032889
# 24589                   -0.052044     -0.032889 -0.02325       -0.032889
# 24590                   -0.052044     -0.032889 -0.02325       -0.032889
# 24593                   -0.052044     -0.032889 -0.02325       -0.032889
# 24594                   -0.052044     -0.032889 -0.02325       -0.032889
# ...                           ...           ...      ...             ...
# 8166                    -0.052044     -0.032889 -0.02325       -0.032889
# 8175                    -0.052044     -0.032889 -0.02325       -0.032889
# 8176                    -0.052044     -0.032889 -0.02325       -0.032889
# 24567                   -0.052044     -0.032889 -0.02325       -0.032889
# 24575                   -0.052044     -0.032889 -0.02325       -0.032889
#
#        mosquito_net
# id
# 24588     -0.040291
# 24589     -0.040291
# 24590     -0.040291
# 24593     -0.040291
# 24594     -0.040291
# ...             ...
# 8166      -0.040291
# 8175      -0.040291
# 8176      -0.040291
# 24567     -0.040291
# 24575     -0.040291
#
# [1364 rows x 122 columns]

# %%
df_price.set_index(df_price["id_unit"],inplace=True)
df_price
# Out:
#                                             name       id  id_unit  id_head  \
# id_unit
# 3623                 CM (1-4) Najam 1 do 4 osobe  3291688     3623    65610
# 23113                CM (1-4) Najam 1 do 4 osobe  3234811    23113    65611
# 3624                 CM (1-4) Najam 1 do 4 osobe  3196314     3624    69418
# 3633     CM 4 Najam  objekta - 4 osobe u objektu  3279524     3633    65907
# 3634                 CM (1-2) Najam 1 do 2 osobe  3279559     3634    65909
# ...                                          ...      ...      ...      ...
# 25727    CM 3 Najam  objekta - 3 osobe u objektu  3284807    25727    69655
# 25729                CM (1-2) Najam 1 do 2 osobe  3274735    25729    69662
# 25785                CM (1-2) Najam 1 do 2 osobe  3290257    25785    69752
# 25787                CM (1-2) Najam 1 do 2 osobe  3290273    25787    69753
# 25788                CM (1-4) Najam 1 do 4 osobe  3290290    25788    69754
#
#          date_start    date_end  amount
# id_unit
# 3623     2022-07-09  2022-08-12   72.00
# 23113    2022-07-09  2022-08-12   72.00
# 3624     2022-07-30  2022-08-12  151.00
# 3633     2022-07-16  2022-08-19   76.49
# 3634     2022-07-16  2022-08-19   54.64
# ...             ...         ...     ...
# 25727    2022-07-16  2022-08-19   80.00
# 25729    2022-07-16  2022-08-19   67.00
# 25785    2022-07-16  2022-08-19   55.00
# 25787    2022-07-16  2022-08-19   55.00
# 25788    2022-07-16  2022-08-19   81.00
#
# [1416 rows x 7 columns]

# %%
for i in df_full["id"]:
    df_full.loc[i,"amount"]=df_price.loc[i,"amount"]
df_full[["id","amount"]]
# Out:
#           id  amount
# id
# 24588  24588  130.00
# 24589  24589  130.00
# 24590  24590  130.00
# 24593  24593  105.00
# 24594  24594  120.00
# ...      ...     ...
# 8166    8166   78.26
# 8175    8175   80.00
# 8176    8176   37.00
# 24567  24567   80.00
# 24575  24575  220.00
#
# [1364 rows x 2 columns]

# %%
ls = df_full.columns[:-1]
ls = ls.insert(3,"amount")

df_final =df_full[ls]
df_final
# Out:
#           id  id_property  beds_basic  amount  backyard  \
# id
# 24588  24588        10043           4  130.00  0.449021
# 24589  24589        10043           4  130.00  0.449021
# 24590  24590        10043           4  130.00  0.449021
# 24593  24593        10046           4  105.00  0.449021
# 24594  24594         9098           4  120.00  0.449021
# ...      ...          ...         ...     ...       ...
# 8166    8166         3559           6   78.26  0.449021
# 8175    8175         3564           4   80.00 -0.985702
# 8176    8176         3564           2   37.00 -0.985702
# 24567  24567        10030           4   80.00  2.037106
# 24575  24575        10039           6  220.00  2.037106
#
#        unit_bedroom_equipment   kitchen  unit_bathroom_equipment  \
# id
# 24588                1.076279  2.243948                 0.106548
# 24589                1.076279  0.275252                 0.949890
# 24590                1.076279  0.871971                -0.727768
# 24593                0.052836 -0.047857                -0.727768
# 24594                1.738705  0.079925                 0.106548
# ...                       ...       ...                      ...
# 8166                 1.980774 -0.559610                 0.949890
# 8175                 1.076279  0.236125                -1.202737
# 8176                 1.076279  6.654588                 0.474920
# 24567                1.980774 -1.262515                -0.780050
# 24575                1.076279 -2.154459                -0.717384
#
#        room_buliding  unit_equipment  ...  in_cable_tv  un_view_river  \
# id                                    ...
# 24588      -1.014682       -0.270266  ...    -0.046537       -0.02325
# 24589      -1.014682       -0.270266  ...    -0.046537       -0.02325
# 24590       1.971703       -0.270266  ...    -0.046537       -0.02325
# 24593      -1.014682       -0.270266  ...    -0.046537       -0.02325
# 24594       1.971703       -0.270266  ...    -0.046537       -0.02325
# ...              ...             ...  ...          ...            ...
# 8166       -1.014682       -0.270266  ...    -0.046537       -0.02325
# 8175       -1.014682       -0.270266  ...    -0.046537       -0.02325
# 8176       -1.014682       -0.270266  ...    -0.046537       -0.02325
# 24567      -1.014682       -0.270266  ...    -0.046537       -0.02325
# 24575       0.469868       -0.270266  ...    -0.046537       -0.02325
#
#        breakfast  description_structure_frontname  \
# id
# 24588  -0.052044                        -0.061612
# 24589  -0.052044                        -0.061612
# 24590  -0.052044                        -0.061612
# 24593  -0.052044                        -0.061612
# 24594  -0.052044                        -0.061612
# ...          ...                              ...
# 8166   -0.052044                        -0.061612
# 8175   -0.052044                        -0.061612
# 8176   -0.052044                        -0.061612
# 24567  -0.052044                        -0.061612
# 24575  -0.052044                        -0.061612
#
#        description_structure_short  description_structure_long  un_view_park  \
# id
# 24588                    -0.057027                   -0.052044     -0.032889
# 24589                    -0.057027                   -0.052044     -0.032889
# 24590                    -0.057027                   -0.052044     -0.032889
# 24593                    -0.057027                   -0.052044     -0.032889
# 24594                    -0.057027                   -0.052044     -0.032889
# ...                            ...                         ...           ...
# 8166                     -0.057027                   -0.052044     -0.032889
# 8175                     -0.057027                   -0.052044     -0.032889
# 8176                     -0.057027                   -0.052044     -0.032889
# 24567                    -0.057027                   -0.052044     -0.032889
# 24575                    -0.057027                   -0.052044     -0.032889
#
#        minibar  meal_room_only  mosquito_net
# id
# 24588 -0.02325       -0.032889     -0.040291
# 24589 -0.02325       -0.032889     -0.040291
# 24590 -0.02325       -0.032889     -0.040291
# 24593 -0.02325       -0.032889     -0.040291
# 24594 -0.02325       -0.032889     -0.040291
# ...        ...             ...           ...
# 8166  -0.02325       -0.032889     -0.040291
# 8175  -0.02325       -0.032889     -0.040291
# 8176  -0.02325       -0.032889     -0.040291
# 24567 -0.02325       -0.032889     -0.040291
# 24575 -0.02325       -0.032889     -0.040291
#
# [1364 rows x 123 columns]

# %%
#df_final.to_csv("gen_data/gen2/final_units2.csv",index=False)

# %% [markdown]
# ### Korelacija s cijenom

# %%
sns.set(rc={'figure.figsize':(25.7,10.27)})

# %%
df_vals = df_final.iloc[:,3:]
corelation1 = df_vals.corr()
color = plt.get_cmap('RdYlGn')   # default color
color.set_bad('lightblue')
color.set_under(color='white')  
color.set_over(color="black")
sns.heatmap(corelation1,annot=False,cmap=color)
# Out:
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_7040\3215834395.py:4: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdYlGn").copy()
#   color.set_bad('lightblue')
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_7040\3215834395.py:5: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdYlGn").copy()
#   color.set_under(color='white')
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_7040\3215834395.py:6: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdYlGn").copy()
#   color.set_over(color="black")
# <AxesSubplot:>

# %%
desc= corelation.describe().dropna(axis=1)

# %%
cols =desc.columns.tolist()
df_vals = df_final.loc[:,cols]
corelation = df_vals.corr()
color = plt.get_cmap('RdYlGn')   
color.set_bad('lightblue')
color.set_under(color='white')  
color.set_over(color="black")
sns.heatmap(corelation,annot=False,cmap=color,vmin = 0.1,vmax=0.9)
# Out:
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_7040\1581867035.py:5: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdYlGn").copy()
#   color.set_bad('lightblue')
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_7040\1581867035.py:6: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdYlGn").copy()
#   color.set_under(color='white')
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_7040\1581867035.py:7: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdYlGn").copy()
#   color.set_over(color="black")
# <AxesSubplot:>

# %%
sns.distplot(df_full["amount"])
# Out:
# C:\Users\Korisnik\anaconda3\envs\AGprojekt\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='amount', ylabel='Density'>

# %%
sns.displot(df_final.loc[:,["amount","area","category","floor"]],x="amount",y="area",hue="category")

# %%
g = sns.PairGrid(df_final.loc[:,["amount","area","category","floor"]])
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %% [markdown]
# ## Korelacija znacajki sa cijenom

# %%
plt.xticks(rotation=90)
sns.scatterplot(data=corelation.iloc[:,0])
# Out:
# <AxesSubplot:ylabel='amount'>

# %%
plt.xticks(rotation=90)
sns.lineplot(data=corelation.iloc[:,:6])
# Out:
# <AxesSubplot:>

# %%
corelation.kitchen
# Out:
# amount                       -0.163297
# backyard                     -0.243892
# unit_bedroom_equipment       -0.297103
# kitchen                       1.000000
# unit_bathroom_equipment      -0.225297
#                                 ...
# description_structure_long   -0.042898
# un_view_park                 -0.014311
# minibar                       0.012039
# meal_room_only                0.145904
# mosquito_net                 -0.029704
# Name: kitchen, Length: 117, dtype: float64

# %%
plt.xticks(rotation=90)
sns.lineplot(data=corelation.loc[:,["amount","kitchen"]])
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=corelation.iloc[:,30:40])
# Out:
# <AxesSubplot:>

# %%
#sns.scatterplot(data=corelation)

# %% [markdown]
# ## Podjela po beds_basic i pregled korelacija

# %%
df_4bed = df_final[df_final["beds_basic"]==4]

# %%
df_vals4 = df_4bed.iloc[:,3:]
corelation4bed = df_vals4.corr()
sns.heatmap(corelation4bed,annot=False)
# Out:
# <AxesSubplot:>

# %%
desc4= corelation4bed.describe().dropna(axis=1)
cols1 =desc4.columns.tolist()
df_vals4 = df_4bed.loc[:,cols1]
corelation4 = df_vals4.corr()
color = plt.get_cmap('RdYlGn')   
color.set_bad('lightblue')
color.set_under(color='white')  
color.set_over(color="black")
sns.heatmap(corelation4,annot=False,cmap=color,vmin = 0.05,vmax=0.9)
# Out:
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_7040\655803473.py:6: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdYlGn").copy()
#   color.set_bad('lightblue')
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_7040\655803473.py:7: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdYlGn").copy()
#   color.set_under(color='white')
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_7040\655803473.py:8: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdYlGn").copy()
#   color.set_over(color="black")
# <AxesSubplot:>

# %%
sns.distplot(df_4bed["amount"])
# Out:
# C:\Users\Korisnik\anaconda3\envs\AGprojekt\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='amount', ylabel='Density'>

# %%
g = sns.PairGrid(df_4bed.loc[:,["amount","area","category","floor"]])
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
plt.xticks(rotation=90)
sns.scatterplot(data=corelation4bed.iloc[:,0])
# Out:
# <AxesSubplot:ylabel='amount'>

# %%
sns.jointplot(data = df_4bed,x = "unit_living_equipment",y="amount",kind="reg",size=10)
# Out:
# C:\Users\Korisnik\anaconda3\envs\AGprojekt\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(data = df_4bed,x = "category",y="amount",kind="reg",size=10)
# Out:
# C:\Users\Korisnik\anaconda3\envs\AGprojekt\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
